# %% [markdown]
# # 1 - Data collection

# %% [markdown]
# Enable progress bars (requires restarting jupyter lab)

# %%
# %%bash
# pip install ipywidgets
# jupyter nbextension enable --py widgetsnbextension
# jupyter labextension install @jupyter-widgets/jupyterlab-manager

# %% [markdown]
# Setup

# %%
import io
from zipfile import ZipFile
import requests as rq
from datetime import date
import pandas as pd
import re

today = date.today().isoformat()

# %%
from IPython.display import Audio
sonar = '../sonar.ogg'

# %% [markdown]
# ## 1.1 Download pipeline system data

# %%
pipelines_2010_present = rq.get('https://www.phmsa.dot.gov/sites/phmsa.dot.gov/files/data_statistics/pipeline/annual_hazardous_liquid_2010_present.zip')
pipelines_2004_2009 = rq.get('https://www.phmsa.dot.gov/sites/phmsa.dot.gov/files/data_statistics/pipeline/annual_hazardous_liquid_2004_2009.zip')

pipelines_2010_present = ZipFile(io.BytesIO(pipelines_2010_present.content))
pipelines_2004_2009 = ZipFile(io.BytesIO(pipelines_2004_2009.content))

pipelines_2010_present.extractall(f'../data/pipelines_2010_present_{today}')
pipelines_2004_2009.extractall(f'../data/pipelines_2004_2009_{today}')

# %%
pipelines_2010_present = pd.read_excel('../data/pipeline_sytem_2019-08-01/annual_hazardous_liquid_2010.xlsx', header=2)

pipelines_2010_present.head()
# Out:
#        DATAFILE_AS_OF  REPORT_YEAR  REPORT_NUMBER  SUPPLEMENTAL_NUMBER  \
# 0 2019-07-01 10:31:50         2010       20110334                12436
# 1 2019-07-01 10:31:50         2010       20110333                10345
# 2 2019-07-01 10:31:50         2010       20110192                10194
# 3 2019-07-01 10:31:50         2010       20110079                10080
# 4 2019-07-01 10:31:50         2010       20110373                10391
#
#    OPERATOR_ID                      PARTA2NAMEOFCOMP  \
# 0          300                 PLAINS PIPELINE, L.P.
# 1          300                 PLAINS PIPELINE, L.P.
# 2          395                          AMOCO OIL CO
# 3          401                      HESS CORPORATION
# 4          402  MARKWEST EAST TEXAS PNG UTILITY, LLC
#
#                            PARTA4STREET        PARTA4CITY PARTA4STATE  \
# 0                       333 CLAY STREET           HOUSTON          TX
# 1                       333 CLAY STREET           HOUSTON          TX
# 2                 150 W. Warrenville Rd  OAKBROOK TERRACE          IL
# 3                  1501 MCKINNEY STREET       BLOOMINGTON          TX
# 4  1515 Arapahoe St, Tower 2, Suite 700            Denver          CO
#
#   PARTA4ZIP  ... PARTE2010HF PARTE2010LF PARTE2010TOTAL PARTETOTAL  \
# 0     77002  ...         0.0         0.0            0.0    1994.32
# 1     77002  ...         0.0         0.0            0.0     256.65
# 2     60563  ...         0.0         0.0            0.0     220.00
# 3     77002  ...         0.0         0.0            0.0      31.50
# 4     80202  ...         0.0         0.0            0.0      49.00
#
#    PARTETOTALHF  PARTETOTALLF  REPORT_SUBMISSION_TYPE         REPORT_DATE  \
# 0        734.12       1260.20            SUPPLEMENTAL 2011-08-15 18:24:50
# 1          6.91        249.74                 INITIAL 2011-08-15 18:24:11
# 2         93.00        127.00                 INITIAL 2011-08-13 16:22:01
# 3         31.50          0.00                 INITIAL 2011-08-10 12:09:38
# 4         49.00          0.00                 INITIAL 2011-08-16 15:29:35
#
#           FILING_DATE                 FORM_REV
# 0 2013-08-08 15:08:42  7000-1.1 (Rev. 06-2011)
# 1 2011-08-15 18:24:11  7000-1.1 (Rev. 06-2011)
# 2 2011-08-13 16:22:01  7000-1.1 (Rev. 06-2011)
# 3 2011-08-10 12:09:38  7000-1.1 (Rev. 06-2011)
# 4 2011-08-16 15:29:35  7000-1.1 (Rev. 06-2011)
#
# [5 rows x 85 columns]

# %% [markdown]
# ## 1.2 Download incidents data

# %%
incidents_file = rq.get('https://www.phmsa.dot.gov/sites/phmsa.dot.gov/files/data_statistics/pipeline/PHMSA_Pipeline_Safety_Flagged_Incidents.zip')
incidents_file = ZipFile(io.BytesIO(incidents_file.content))

incidents_file.extractall(f'../data/incidents_{today}')

# %%
incidents = pd.read_excel('../data/incidents_2019-08-01/hl2010toPresent.xlsx', sheet_name=1)

incidents.head()
# Out:
#        DATAFILE_AS_OF SIGNIFICANT SERIOUS IPE IA_IPE OM_IPE  REPORT_NUMBER  \
# 0 2019-07-31 08:37:40          NO      NO  NO     NO     NO       20100001
# 1 2019-07-31 08:37:40          NO      NO  NO     NO     NO       20100002
# 2 2019-07-31 08:37:40         YES      NO  NO     NO     NO       20100003
# 3 2019-07-31 08:37:40          NO      NO  NO     NO     NO       20100004
# 4 2019-07-31 08:37:40          NO      NO  NO     NO     NO       20100005
#
#    SUPPLEMENTAL_NUMBER REPORT_RECEIVED_DATE         REPORT_TYPE  ...  \
# 0                15751  2010-03-10 13:05:46  SUPPLEMENTAL FINAL  ...
# 1                19837  2010-03-16 17:43:54  SUPPLEMENTAL FINAL  ...
# 2                18021  2010-03-17 10:38:15  SUPPLEMENTAL FINAL  ...
# 3                19086  2010-03-18 13:18:48  SUPPLEMENTAL FINAL  ...
# 4                17663  2010-03-18 14:26:48  SUPPLEMENTAL FINAL  ...
#
#                                       PREPARER_TITLE  \
# 0                      SENIOR COMPLIANCE COORDINATOR
# 1                               SR. PIPELINE TECH II
# 2                   DIRECTOR - REGULATORY COMPLIANCE
# 3                                 COMPLIANCE MANAGER
# 4  ENVIRONMENTAL REMEDIATION AND COMPLIANCE SPECI...
#
#                      PREPARER_EMAIL PREPARER_TELEPHONE  PREPARER_FAX  \
# 0       ken.lybarger@magellanlp.com       918-574-7315  918-574-7246
# 1   gabe.mccown@chaparralenergy.com       405-426-4361           NaN
# 2  danny.nichols@energytransfer.com       326-681-006            NaN
# 3             jreinbold@buckeye.com       610-904-4185  610-904-4545
# 4                hltuggle@paalp.com       713-646-4324  713-646-4310
#
#   PREPARED_DATE      AUTHORIZER_NAME  \
# 0    2011-04-15  KENNETH L. LYBARGER
# 1    2014-10-28          DAVE YEAGER
# 2    2013-05-10        DANNY NICHOLS
# 3    2014-03-06        JOHN REINBOLD
# 4    2013-03-22      WARREN FUSILIER
#
#                                     AUTHORIZER_TITLE  AUTHORIZER_TELEPHONE  \
# 0                      SENIOR COMPLIANCE COORDINATOR          918-574-7315
# 1                                   PIPELINE MANAGER          405-255-6581
# 2                   DIRECTOR - REGULATORY COMPLIANCE          326-681-006
# 3                                 COMPLIANCE MANAGER          610-904-4185
# 4  DIRECTOR - ENVIRONMENTAL AND REMEDIATION-COMPL...          713-646-4515
#
#                    AUTHORIZER_EMAIL  \
# 0       ken.lybarger@magellanlp.com
# 1   dave.yeager@chaparralenergy.com
# 2  danny.nichols@energytransfer.com
# 3             jreinbold@buckeye.com
# 4              wdfusilier@paalp.com
#
#                                            NARRATIVE
# 0                                                NaN
# 1  AT 11:50 AM ON THE MORNING OF MARCH 1, 2010 A ...
# 2  LEAK DISCOVERED BY CONTRACTOR WORKING FOR ANOT...
# 3  AT 6:50 AM ON FEBRUARY 19, 2010, BUCKEYE PERSO...
# 4  INTERNAL CORROSION ON 10-INCH PIPELINE RESULTE...
#
# [5 rows x 606 columns]

# %% [markdown]
# ## 1.3 Download FERC notices

# %% [markdown]
# ### Download list of all notices

# %%
api = 'https://www.federalregister.gov/api/v1/documents.json'

params = {'fields[]': ['document_number', 'publication_date', 'title', 'raw_text_url'], 
          'per_page': 1000, 
          'order': 'oldest', 
          'conditions[agencies][]': 'federal-energy-regulatory-commission', 
          'conditions[type][]': 'NOTICE'}

# %% [markdown]
# Iterate over all pages of one search (for one year) and download data on all documents (before downloading the full-text of all documents

# %%
import requests as rq

def get_documents(api, params, year):
    params['conditions[publication_date][year]'] = year
    max_page = 9999
    page = 1
    notices = []
    while page <= max_page:
        params['page'] = page
        with rq.get(api, params=params) as response:
            overview = response.json()

            max_page = overview['total_pages']
            print(f'Loaded year {year}, page {page} of {max_page}.')

            results = overview['results']
            notices = notices + results
        
        page += 1
        
    return notices

# %% [markdown]
# Collect all data from 2005-2019, except full-text

# %%
notices = []
for year in range(2005, 2020):
    notices = notices + get_documents(api=api, params=params, year=year)
# Out:
# Loaded year 2005, page 1 of 3.
# Loaded year 2005, page 2 of 3.
# Loaded year 2005, page 3 of 3.
# Loaded year 2006, page 1 of 3.
# Loaded year 2006, page 2 of 3.
# Loaded year 2006, page 3 of 3.
# Loaded year 2007, page 1 of 3.
# Loaded year 2007, page 2 of 3.
# Loaded year 2007, page 3 of 3.
# Loaded year 2008, page 1 of 2.
# Loaded year 2008, page 2 of 2.
# Loaded year 2009, page 1 of 2.
# Loaded year 2009, page 2 of 2.
# Loaded year 2010, page 1 of 2.
# Loaded year 2010, page 2 of 2.
# Loaded year 2011, page 1 of 2.
# Loaded year 2011, page 2 of 2.
# Loaded year 2012, page 1 of 3.
# Loaded year 2012, page 2 of 3.
# Loaded year 2012, page 3 of 3.
# Loaded year 2013, page 1 of 2.
# Loaded year 2013, page 2 of 2.
# Loaded year 2014, page 1 of 2.
# Loaded year 2014, page 2 of 2.
# Loaded year 2015, page 1 of 2.
# Loaded year 2015, page 2 of 2.
# Loaded year 2016, page 1 of 2.
# Loaded year 2016, page 2 of 2.
# Loaded year 2017, page 1 of 2.
# Loaded year 2017, page 2 of 2.
# Loaded year 2018, page 1 of 2.
# Loaded year 2018, page 2 of 2.
# Loaded year 2019, page 1 of 1.

# %%
import pandas as pd
notices = pd.DataFrame(notices)

notices.head()
# Out:
#   document_number publication_date  \
# 0         E4-3915       2005-01-04
# 1         E4-3918       2005-01-04
# 2           05-18       2005-01-04
# 3         E4-3919       2005-01-04
# 4         E4-3920       2005-01-04
#
#                                                title  \
# 0  Young Gas Storage Company, Ltd.; Notice of Pro...
# 1  Sea Robin Pipeline Company; Notice of Flowthro...
# 2  Survey on Operator Training Practices; Order R...
# 3  Dauphin Island Gathering Partners; Notice of P...
# 4  Transcontinental Gas Pipe Line Corporation; No...
#
#                                         raw_text_url
# 0  https://www.federalregister.gov/documents/full...
# 1  https://www.federalregister.gov/documents/full...
# 2  https://www.federalregister.gov/documents/full...
# 3  https://www.federalregister.gov/documents/full...
# 4  https://www.federalregister.gov/documents/full...

# %% [markdown]
# ### Paralellize download of sites

# %%
import re
import tqdm
from requests import Session
from multiprocessing import Pool
from tqdm import tqdm_notebook as tqdm

def download_site(url):
    with session.get(url) as response:
        return response.text
    
def download_all_sites(sites, preprocessing=None, processes=8):
    with Pool(processes=processes) as pool:
        results = tqdm(pool.imap(download_site, sites), total=len(sites))
        if preprocessing:
            results = map(preprocessing, results)
        return list(results)

# %% [markdown]
# We will need this function to clean the individual documents we download

# %%
def clean_notice(notice):
    return re.findall('<pre>(.*)</pre>', notice, flags=re.DOTALL)

# %%
session = Session()

notices['full-text'] = download_all_sites(list(notices['raw_text_url']), preprocessing=clean_notice, processes=7)
# Out:
# HBox(children=(IntProgress(value=0, max=27890), HTML(value='')))

# %%
Audio(sonar, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
notices.tail()
# Out:
#       document_number publication_date  \
# 27885      2019-16277       2019-07-31
# 27886      2019-16274       2019-07-31
# 27887      2019-16276       2019-07-31
# 27888      2019-16278       2019-07-31
# 27889      2019-16275       2019-07-31
#
#                                                    title  \
# 27885                      Combined Notice of Filings #1
# 27886  Notice Soliciting Scoping Comments: Turners Fa...
# 27887  Gulfstream Natural Gas System, L.L.C.; Notice ...
# 27888  Records Governing Off-the-Record Communication...
# 27889  Emmons-Logan Wind, LLC; Supplemental Notice Th...
#
#                                             raw_text_url  \
# 27885  https://www.federalregister.gov/documents/full...
# 27886  https://www.federalregister.gov/documents/full...
# 27887  https://www.federalregister.gov/documents/full...
# 27888  https://www.federalregister.gov/documents/full...
# 27889  https://www.federalregister.gov/documents/full...
#
#                                                full-text
# 27885  [[Federal Register Volume 84, Number 147 (Wedn...
# 27886  [[Federal Register Volume 84, Number 147 (Wedn...
# 27887  [[Federal Register Volume 84, Number 147 (Wedn...
# 27888  [[Federal Register Volume 84, Number 147 (Wedn...
# 27889  [[Federal Register Volume 84, Number 147 (Wedn...

# %%
notices.to_csv(f'../data/ferc_notices_{today}.csv')
